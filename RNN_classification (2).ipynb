# %%
import glob # поиск файлов, удовлетворающих условию
import os
import unicodedata
import string
import io

# %%
for i in glob.glob('/content/drive/MyDrive/Colab Notebooks/data/names/*txt'): # перебор всех файлов
  print(len(open(i).readlines()))
# Out:
# 298
# 2000
# 232
# 139
# 709
# 94
# 74
# 268
# 203
# 9408
# 991
# 73
# 519
# 3668
# 100
# 277
# 724
# 297

# %% [markdown]
# Для начала нужно добавить функцию для перевода символов из Unicode в Ascii, что позволит уменьшить разброс классификации, сужая круг поиска класса. То есть сеть не будте различать символы, различающиеся апострофами, так как они встречаются редко. (строка 5).
#
# Далее создадим словарь category_lines, ключи в котором будут представлять язык, а значения - списки с именами, и список с языками all_categories, состоящий из языков из датасета

# %%
all_letters = string.ascii_letters + " .,;'" # метод возвращает строку с символами обоих регистров и конкатенирует их
n_letters = len(all_letters)
print('Символы: ', all_letters)

def unicodeToAscii(s): # функция заменяет символы на стандартные из unicode
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
        and c in all_letters
    )

print(unicodeToAscii('Śáý'))

# Создадим словарь category_lines и список с языками all_categories
category_lines = {}
all_categories = []

# разделение файла на строки
def readLines(filename):
    lines = io.open(filename, encoding='utf-8').read().strip().split('\n')
    return [unicodeToAscii(line) for line in lines]

for filename in glob.glob('/content/drive/MyDrive/Colab Notebooks/data/names/*.txt'):
    category = os.path.splitext(os.path.basename(filename))[0] # считывание названия файла для классификации
    all_categories.append(category) # добавление категории в список
    lines = readLines(filename) # помещение всех строк в список (readlines)
    category_lines[category] = lines # добавление имени в словарь к соответствующему ключу category

n_categories = len(all_categories)
print('Количество языков:', len(category_lines))
# Out:
# Символы:  abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ .,;'
# Say
# Количество языков: 18

# %% [markdown]
# Теперь в словаре category_lines содержатся все языки из файла в виде ключей, а также все имена в списке в виде значений

# %%
# список ключей (языков)
for i in category_lines:
    (print(i, len(category_lines.get(i)), end=' '))
# Out:
# Spanish 298 Arabic 2000 Irish 232 Polish 139 Italian 709 Korean 94 Portuguese 74 Chinese 268 Greek 203 Russian 9408 Japanese 991 Vietnamese 73 Czech 519 English 3668 Scottish 100 French 277 German 724 Dutch 297

# %%
 import torch
# letterToIndex - позиция буквы в алфавите
# letterToTensor - матрица из слова
# lineToTensor - слово в трехмерной матрице
# функция для определения позиции буквы в местном алфавите (all_letters). Аналог ord (косвенно)
def letterToIndex(letter):
    return all_letters.find(letter)

# добавление буквы в Тензор (одномерная матрица)
def letterToTensor(letter):
    tensor = torch.zeros(1, n_letters) # возвращает матрицу 1 на n_latters
    tensor[0][letterToIndex(letter)] = 1 # индекс порядкового места буквы заменяется на 1
    return tensor


def lineToTensor(line): # --> матрица [[a] на [b] на [c]], где
# a - коилчество символов в строке
# b - 1
# c - количество символов (57)
    tensor = torch.zeros(len(line), 1, n_letters) # двумерная матрица c нулевыми значениями
    for li, letter in enumerate(line):
        tensor[li][0][letterToIndex(letter)] = 1
    return tensor

print
print(lineToTensor('abbc').size())
# Out:
# torch.Size([4, 1, 57])

# %%
print(lineToTensor('acc').size())
# Out:
# torch.Size([3, 1, 57])

# %% [markdown]
# ## Обучение

# %% [markdown]
# В  PyTorch уже есть готовый объект RNN, готовый к использованию

# %%
import torch.nn as nn
# класс с Pytorch
class RNN(nn.Module): # наследование базового класса
    def __init__(self, input_size, hidden_size, output_size):
        super(RNN, self).__init__()

        self.hidden_size = hidden_size # количество функций в скрытом состоянии h
# следующие 3 строки - соединенные слои, как показано на диаграмме.
# представленный слой - объект nn.Linear. В качестве аргументов количество узлов в i и i + 1 слоях
        self.i2h = nn.Linear(input_size + hidden_size, hidden_size)
        self.h2o = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden): # фиктивный метод для движения по сети
        combined = torch.cat((input, hidden), 1)
        hidden = self.i2h(combined)
        output = self.h2o(hidden)
        output = self.softmax(output)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, self.hidden_size) # матрица 1 на 128 - скрытый узел

# первый слой - количество букв, второй слой -, третий - количество языков,
# так как их мы и будем классифицировать
n_hidden = 128
rnn = RNN(n_letters, n_hidden, n_categories)

# %% [markdown]
# Для запуска сети нужно создать ввод буквы, функция вернет вероятности принадлежности каждой языковой группе и вероятность следующей буквы. <br>
# В качестве аргумента функции zeros ипользуется скрытый слой(пока заполненный нулями) и номер буквы

# %%
input = letterToTensor('O')
hidden = torch.zeros(1, n_hidden)

output, next_hidden = rnn(input, hidden)
print(output)
print(next_hidden)
# Out:
# tensor([[-2.9718, -2.8728, -2.8543, -2.8891, -2.8209, -2.8311, -2.9504, -2.9686,
#          -2.7972, -2.9217, -3.0009, -2.8008, -2.8401, -2.9399, -2.9118, -2.9316,
#          -2.9498, -2.8105]], grad_fn=<LogSoftmaxBackward0>)
# tensor([[-0.0007,  0.1242, -0.0664, -0.0281,  0.0261, -0.0464,  0.0323,  0.0020,
#           0.0075, -0.0042,  0.0505,  0.1070, -0.1326,  0.0971, -0.0006,  0.0255,
#           0.1001,  0.1061,  0.0624, -0.0174,  0.0587, -0.0168, -0.0044, -0.0498,
#           0.0066,  0.0283, -0.0647,  0.0322,  0.0594, -0.1003, -0.0288,  0.0008,
#          -0.0858, -0.0223, -0.0855, -0.0172, -0.0080, -0.0112, -0.0280, -0.0712,
#           0.0934, -0.0896,  0.1089,  0.0325, -0.0628,  0.1037,  0.0668, -0.0439,
#          -0.0393,  0.0304,  0.0494,  0.0669, -0.0080, -0.0482, -0.1301, -0.0555,
#          -0.0246,  0.0506,  0.0438,  0.0817,  0.0226,  0.0010, -0.0257, -0.0022,
#          -0.0425, -0.0583,  0.0580, -0.1307,  0.0132,  0.0126, -0.0108,  0.0322,
#          -0.0124, -0.0057,  0.0088, -0.0131,  0.0221,  0.0058,  0.0170, -0.0701,
#          -0.0242, -0.0152,  0.0839, -0.0490,  0.0185,  0.1405,  0.0051,  0.0731,
#           0.1013,  0.1124, -0.0401,  0.0681, -0.0968,  0.0285, -0.0867,  0.0452,
#           0.0784, -0.0126,  0.0662, -0.0269, -0.0401, -0.0002, -0.0980, -0.0749,
#           0.0647, -0.0465,  0.0239,  0.0358, -0.0346, -0.0098, -0.0055,  0.0577,
#           0.0618, -0.0209, -0.0274, -0.0934, -0.0852, -0.0179,  0.0383, -0.0423,
#          -0.0214, -0.0660, -0.0165,  0.0963, -0.0799,  0.0031, -0.0030,  0.0978]],
#        grad_fn=<AddmmBackward0>)

# %%
# в экземмпляре модели видна архитектура - первый узел - 57 букв + 128 элементов другого узла,
# далее 2 узла с размерностью 127 и 18
print(rnn)
print(n_letters, n_categories)
# Out:
# RNN(
#   (i2h): Linear(in_features=185, out_features=128, bias=True)
#   (h2o): Linear(in_features=128, out_features=18, bias=True)
#   (softmax): LogSoftmax(dim=1)
# )
# 57 18

# %% [markdown]
# Чтобы постоянно не создавать новйы тензор, можно воспользоваться написанной ранее функцией LineToTensor и использовать взятие по индексу или срезы. функция вернет вероятности принадлежности к языковым группам

# %%
input = lineToTensor('Ivan')
hidden = torch.zeros(1, n_hidden)

output, next_hidden = rnn(input[0], hidden)
print(output)
# Out:
# tensor([[-2.9932, -2.9050, -2.8069, -2.9231, -2.7966, -2.8188, -2.9870, -2.9157,
#          -2.8028, -2.9700, -2.9802, -2.8323, -2.8209, -2.9381, -2.8984, -2.9315,
#          -2.9478, -2.8025]], grad_fn=<LogSoftmaxBackward0>)

# %% [markdown]
# ### Тренировка сети

# %%
def categoryFromOutput(output):
    top_n, top_i = output.topk(1)
    print(output.topk(1))
    category_i = top_i[0].item()
    return all_categories[category_i], category_i
print(categoryFromOutput(output))
# Out:
# torch.return_types.topk(
# values=tensor([[-2.7966]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# ('Italian', 4)

# %%
import random
# функция для выбора случайного индекса списка
def randomChoice(l):
    return l[random.randint(0, len(l) - 1)]
#
def randomTrainingExample():
    category = randomChoice(all_categories) # случайная языковая категория в переменной category
    line = randomChoice(category_lines[category]) # случайное имя в выбранном языке
    category_tensor = torch.tensor([all_categories.index(category)], dtype=torch.long) # тензор вида tensor([индекс группы])
    line_tensor = lineToTensor(line) # матрица 1 на 57 на длину имени
    return category, line, category_tensor, line_tensor

# %% [markdown]
# # Непосредственно тренировка

# %%
criterion = nn.NLLLoss()

# %%
learning_rate = 0.005 # leraning rate - размер шага обучения при движении к минимуму функции потерь

def train(category_tensor, line_tensor):
    hidden = rnn.initHidden()

    rnn.zero_grad()

    for i in range(line_tensor.size()[0]):
        output, hidden = rnn(line_tensor[i], hidden)

    loss = criterion(output, category_tensor)
    loss.backward()

    for p in rnn.parameters():
        p.data.add_(p.grad.data, alpha=-learning_rate)

    return output, loss.item()

# %%
learning_rate = 0.005

def train(category_tensor, line_tensor):
    hidden = rnn.initHidden()

    rnn.zero_grad()

    for i in range(line_tensor.size()[0]):
        output, hidden = rnn(line_tensor[i], hidden)

    loss = criterion(output, category_tensor)
    loss.backward()

    for p in rnn.parameters():
        p.data.add_(p.grad.data, alpha=-learning_rate)

    return output, loss.item()

# %%
import time
import math

n_iters = 100000
print_every = 5000
plot_every = 1000


# Отслеживание состояния потерь
current_loss = 0
all_losses = []

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

start = time.time()

for iter in range(1, n_iters + 1):
    category, line, category_tensor, line_tensor = randomTrainingExample()
    output, loss = train(category_tensor, line_tensor)
    current_loss += loss

    if iter % print_every == 0:
        guess, guess_i = categoryFromOutput(output)
        correct = '✓' if guess == category else '✗ (%s)' % category
        print('%d %d%% (%s) %.4f %s / %s %s' % (iter, iter / n_iters * 100, timeSince(start), loss, line, guess, correct))


    if iter % plot_every == 0:
        all_losses.append(current_loss / plot_every)
        current_loss = 0
# Out:
# torch.return_types.topk(
# values=tensor([[-1.6872]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# 5000 5% (0m 5s) 3.0529 Hassani / Japanese ✗ (English)
# torch.return_types.topk(
# values=tensor([[-0.9460]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# 10000 10% (0m 9s) 3.5875 Morcos / Greek ✗ (Arabic)
# torch.return_types.topk(
# values=tensor([[-1.4285]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# 15000 15% (0m 14s) 1.4852 See  / Korean ✗ (Chinese)
# torch.return_types.topk(
# values=tensor([[-0.8766]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# 20000 20% (0m 22s) 0.8766 Kang / Chinese ✓
# torch.return_types.topk(
# values=tensor([[-0.7687]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# 25000 25% (0m 28s) 0.7687 Thao / Vietnamese ✓
# torch.return_types.topk(
# values=tensor([[-0.2296]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# 30000 30% (0m 33s) 0.2296 Rutkowski / Polish ✓
# torch.return_types.topk(
# values=tensor([[-0.9649]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# 35000 35% (0m 40s) 0.9649 Kattan / Arabic ✓
# torch.return_types.topk(
# values=tensor([[-0.7161]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# 40000 40% (0m 45s) 3.5774 Kim / Korean ✗ (Vietnamese)
# torch.return_types.topk(
# values=tensor([[-1.5197]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# 45000 45% (0m 51s) 3.4858 Aalst / English ✗ (Dutch)
# torch.return_types.topk(
# values=tensor([[-1.0005]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# 50000 50% (0m 56s) 3.5054 Gaspar / Arabic ✗ (Portuguese)
# torch.return_types.topk(
# values=tensor([[-0.3381]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# 55000 55% (1m 0s) 0.3381 Kwak / Korean ✓
# torch.return_types.topk(
# values=tensor([[-1.3326]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# 60000 60% (1m 5s) 1.3931 Lesauvage / Greek ✗ (French)
# torch.return_types.topk(
# values=tensor([[-1.3033]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# 65000 65% (1m 9s) 1.3033 Alves / Spanish ✓
# torch.return_types.topk(
# values=tensor([[-1.1359]], grad_fn=<TopkBackward0>),
# indices=tensor([[17]]))
# 70000 70% (1m 18s) 1.1359 Ophoven / Dutch ✓
# torch.return_types.topk(
# values=tensor([[-0.7227]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# 75000 75% (1m 23s) 0.7227 Araullo / Portuguese ✓
# torch.return_types.topk(
# values=tensor([[-0.1888]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# 80000 80% (1m 27s) 0.1888 Sasada / Japanese ✓
# torch.return_types.topk(
# values=tensor([[-1.0476]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# 85000 85% (1m 32s) 2.3720 Bissette / Scottish ✗ (French)
# torch.return_types.topk(
# values=tensor([[-0.3480]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# 90000 90% (1m 36s) 3.2096 Bruckner / German ✗ (Czech)
# torch.return_types.topk(
# values=tensor([[-0.8743]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# 95000 95% (1m 40s) 0.8743 Chi / Korean ✓
# torch.return_types.topk(
# values=tensor([[-0.3061]], grad_fn=<TopkBackward0>),
# indices=tensor([[2]]))
# 100000 100% (1m 45s) 0.3061 O'Brien / Irish ✓

# %% [markdown]
# #3

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.figure()
plt.plot(all_losses)

# %% [markdown]
# Для анализа рещультата создается матрциа, показывающая, какой язык угадала нейросеть. Для этого используется аналогичная train функци evaluate. В матрице по горизонтали идут использованные языки, по вертикали - ответ нейросети

# %%
confusion = torch.zeros(n_categories, n_categories)
n_confusion = 10000
def evaluate(line_tensor):
    hidden = rnn.initHidden()

    for i in range(line_tensor.size()[0]):
     output, hidden = rnn(line_tensor[i], hidden)

    return output

for i in range(n_confusion):
    category, line, category_tensor, line_tensor = randomTrainingExample()
    output = evaluate(line_tensor)
    guess, guess_i = categoryFromOutput(output)
    category_i = all_categories.index(category)
    confusion[category_i][guess_i] += 1

for i in range(n_categories):
    confusion[i] = confusion[i] / confusion[i].sum()

fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(confusion.numpy())
fig.colorbar(cax)

ax.set_xticklabels([''] + all_categories, rotation=90)
ax.set_yticklabels([''] + all_categories)

ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))


plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# values=tensor([[-0.3020]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.8949]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.4801]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-1.4237]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-1.7338]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.9249]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.3962]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-0.7335]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.8711]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.6856]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.8604]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.5466]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-1.4194]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-1.2739]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.5487]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.2275]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.2830]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-1.0118]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-1.3847]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.0959]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.0025]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.6583]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-1.0261]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.6892]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.4421]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.0854]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.0020]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.7554]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.5989]], grad_fn=<TopkBackward0>),
# indices=tensor([[17]]))
# torch.return_types.topk(
# values=tensor([[-0.4191]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.7742]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.5367]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.9105]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.0573]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-1.0487]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.4920]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.2442]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-1.8205]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.7632]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.0344]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.7418]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.8453]], grad_fn=<TopkBackward0>),
# indices=tensor([[17]]))
# torch.return_types.topk(
# values=tensor([[-1.2899]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.6864]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.1757]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.0325]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.0580]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.6519]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.9048]], grad_fn=<TopkBackward0>),
# indices=tensor([[2]]))
# torch.return_types.topk(
# values=tensor([[-0.5889]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.8543]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.2242]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.2381]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.0011]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.3748]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.5027]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.2802]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.9526]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.0031]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.1668]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.5281]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.2332]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-1.2711]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-1.0611]], grad_fn=<TopkBackward0>),
# indices=tensor([[17]]))
# torch.return_types.topk(
# values=tensor([[-0.2994]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.9541]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.7568]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.4006]], grad_fn=<TopkBackward0>),
# indices=tensor([[17]]))
# torch.return_types.topk(
# values=tensor([[-0.5588]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.9824]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-1.0071]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.1642]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-1.5778]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.0494]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-0.0075]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.4165]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.2312]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.9614]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.7502]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.1179]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.2005]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.3847]], grad_fn=<TopkBackward0>),
# indices=tensor([[2]]))
# torch.return_types.topk(
# values=tensor([[-1.3517]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.3700]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.2449]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.3886]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-1.0575]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.7618]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.4842]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.2650]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.3886]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.7867]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-1.1505]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-1.0829]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.6679]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.0008]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.1554]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.4132]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.3291]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.9229]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.2933]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-0.1960]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.8784]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-1.2525]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.2422]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.9135]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-1.0189]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-1.3191]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.7872]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.7647]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.4165]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.0002]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.0540]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.9344]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.9249]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.3668]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.4730]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.5621]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.1291]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.2275]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.3239]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.8094]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.0323]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.2527]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.1969]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-1.1416]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.1402]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.7545]], grad_fn=<TopkBackward0>),
# indices=tensor([[17]]))
# torch.return_types.topk(
# values=tensor([[-0.7572]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.7551]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.2237]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.4187]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.6131]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.8406]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.0603]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.9616]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-1.1863]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.4664]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.4664]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.0280]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.0825]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.7853]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.0053]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.1176]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.0479]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-7.7483e-05]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.6444]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.0482]], grad_fn=<TopkBackward0>),
# indices=tensor([[17]]))
# torch.return_types.topk(
# values=tensor([[-0.2139]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.6145]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.9930]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.1999]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.7461]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-1.2833]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.4248]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.6398]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.1795]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.5230]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.6506]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.2106]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-0.4956]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.7655]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.9262]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.2206]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.1617]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.0280]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.4165]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.7914]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.4456]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.9754]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.3735]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.4723]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.8587]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.4041]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.4787]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.4803]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.5920]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.8851]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-1.0960]], grad_fn=<TopkBackward0>),
# indices=tensor([[17]]))
# torch.return_types.topk(
# values=tensor([[-1.1271]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.1139]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.7579]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-1.1767]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.3599]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.8205]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.3214]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.5806]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.1251]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.9422]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.1961]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.1416]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.9983]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.0001]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.5400]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.2488]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.6184]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.5709]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.5534]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.0002]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.4106]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.1343]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.1058]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.6211]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.8934]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-1.4833]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-1.5323]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.5849]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.9062]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-1.0198]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.5600]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.4844]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.4475]], grad_fn=<TopkBackward0>),
# indices=tensor([[17]]))
# torch.return_types.topk(
# values=tensor([[-0.7796]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-1.1167]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.9750]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.3493]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.6305]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.5857]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-1.2531]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-1.3909]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.2999]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.1316]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-1.1133]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.8336]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-1.5675]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.7368]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-1.1617]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.2860]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-1.2835]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-1.0339]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.3490]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.6220]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.6159]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-1.5323]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-1.4833]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-1.4300]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.0421]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-1.0061]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.0986]], grad_fn=<TopkBackward0>),
# indices=tensor([[2]]))
# torch.return_types.topk(
# values=tensor([[-0.6214]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.1521]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.9276]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.8122]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.0640]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.2610]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-1.0577]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.3962]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-0.2203]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-1.0584]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-1.1235]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.0632]], grad_fn=<TopkBackward0>),
# indices=tensor([[2]]))
# torch.return_types.topk(
# values=tensor([[-1.3408]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.5447]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-1.1345]], grad_fn=<TopkBackward0>),
# indices=tensor([[17]]))
# torch.return_types.topk(
# values=tensor([[-0.1225]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.1264]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.3874]], grad_fn=<TopkBackward0>),
# indices=tensor([[2]]))
# torch.return_types.topk(
# values=tensor([[-0.3989]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.7345]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.0270]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.1815]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.8947]], grad_fn=<TopkBackward0>),
# indices=tensor([[17]]))
# torch.return_types.topk(
# values=tensor([[-0.9048]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.8047]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-1.3316]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.5929]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-1.1416]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-1.0360]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-0.1961]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.8479]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.9959]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-1.2397]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-1.8271]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-1.2438]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.2030]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-1.2172]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.4850]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-1.2281]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-1.1777]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.8845]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.5051]], grad_fn=<TopkBackward0>),
# indices=tensor([[17]]))
# torch.return_types.topk(
# values=tensor([[-0.1049]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.6422]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.0237]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.3371]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.7899]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-1.1054]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.6583]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.1191]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.8731]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.1864]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-1.0204]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.6332]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.0011]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.0893]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.3826]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.2900]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-1.2172]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.9919]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.0028]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.8047]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-1.2986]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-1.0981]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.6434]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.1944]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.4859]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.1058]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-1.1795]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.9566]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-1.2421]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-1.4297]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.8059]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.7825]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.3823]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-0.6540]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.4723]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-1.5398]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.0355]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.1555]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-1.2347]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.5157]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-0.7107]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.2994]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.7478]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.0016]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.7359]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.0180]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.0412]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.4825]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.1359]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.1244]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.6957]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.0822]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.6282]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.2469]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.3070]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.3120]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.1867]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.1773]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.9285]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.6499]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.9178]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-1.0805]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.7188]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.8501]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.9249]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-1.7171]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.7233]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.5463]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.5518]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.6845]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.5249]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.3282]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.0233]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.8092]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-1.2533]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.6193]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.7395]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-1.2749]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.0233]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.1757]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.0080]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.2870]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.0614]], grad_fn=<TopkBackward0>),
# indices=tensor([[2]]))
# torch.return_types.topk(
# values=tensor([[-0.8722]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-1.3817]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.6366]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.8033]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.6478]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.1502]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.6062]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.2236]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.7461]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.8732]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-1.0445]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.5104]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.1855]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.5319]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.4882]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.5465]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.0087]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.4300]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-1.3998]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.6453]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.2919]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-1.0577]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.9377]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.3985]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.3490]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.1757]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.6884]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.0780]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-1.3203]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.3003]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-0.8806]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.7705]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-1.3106]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.6873]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-1.0195]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.0824]], grad_fn=<TopkBackward0>),
# indices=tensor([[2]]))
# torch.return_types.topk(
# values=tensor([[-0.7829]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.2480]], grad_fn=<TopkBackward0>),
# indices=tensor([[2]]))
# torch.return_types.topk(
# values=tensor([[-0.6642]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.0096]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.9908]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-1.0339]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.1343]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.5512]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.1416]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-1.0061]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.1521]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.9505]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-1.2275]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.5423]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.1834]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.7372]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.2735]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.3208]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.0003]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.0361]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-1.1989]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.4995]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-1.1035]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.8576]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.7657]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.0069]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.2828]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.6081]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-1.0367]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.5767]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.8194]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-1.1572]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.1803]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.2463]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.7784]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.9854]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.4108]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.5895]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-1.3159]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.4803]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.6892]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.7914]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.0718]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-1.2896]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-1.1989]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.2822]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.8521]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.3916]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.3490]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.6762]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-1.0623]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.7491]], grad_fn=<TopkBackward0>),
# indices=tensor([[17]]))
# torch.return_types.topk(
# values=tensor([[-0.6694]], grad_fn=<TopkBackward0>),
# indices=tensor([[17]]))
# torch.return_types.topk(
# values=tensor([[-1.3439]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.3003]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-0.9291]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.2415]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.5059]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.8405]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-1.2430]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.7009]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.0269]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-1.1452]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.4126]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.2588]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.2822]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.1642]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.3540]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-1.1043]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-1.8067]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-1.0010]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.6762]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.1728]], grad_fn=<TopkBackward0>),
# ...
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.9824]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.4336]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.7391]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.7359]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.0192]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.4456]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.2469]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.0298]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.6053]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.1757]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.6681]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.6924]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.0102]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.5823]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.9403]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.9493]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.4503]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.5607]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.1502]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.3087]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.8837]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.7946]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.5724]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.4868]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.5799]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.3025]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.1058]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-1.6891]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-1.1698]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.8214]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.5433]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.2783]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-1.5288]], grad_fn=<TopkBackward0>),
# indices=tensor([[2]]))
# torch.return_types.topk(
# values=tensor([[-1.0062]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.3962]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-0.7689]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.6237]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.5433]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.9271]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.9954]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-1.2727]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.8581]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.0861]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.5416]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.9948]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.9970]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.2528]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.2387]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.3824]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.9748]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.1148]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.9802]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.2822]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-1.0017]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-1.2959]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.0791]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.2768]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.3039]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.6274]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.6924]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.9773]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.2055]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.1148]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.1706]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.3849]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.6991]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-1.3275]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.1301]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.8837]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.1814]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.3048]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.2646]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-1.1967]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-1.4194]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-0.1677]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.3384]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.0006]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.5433]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.7495]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.4827]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.2630]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.3739]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-1.0026]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.7372]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-1.3686]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.9607]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-1.2845]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-1.3978]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.7815]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.5443]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-1.0633]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-1.5646]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.7397]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-0.7518]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.5742]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-1.1513]], grad_fn=<TopkBackward0>),
# indices=tensor([[17]]))
# torch.return_types.topk(
# values=tensor([[-0.4159]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-1.2835]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.7461]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.0968]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.4872]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.3599]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.9780]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.3989]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-0.5524]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.6171]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.9178]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-0.8573]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.1388]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.8837]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.5469]], grad_fn=<TopkBackward0>),
# indices=tensor([[12]]))
# torch.return_types.topk(
# values=tensor([[-0.8028]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-1.1054]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.8311]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.9582]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-1.1184]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.1120]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.8860]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-1.5675]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-1.0302]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-1.0989]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-1.0079]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.8677]], grad_fn=<TopkBackward0>),
# indices=tensor([[6]]))
# torch.return_types.topk(
# values=tensor([[-1.2677]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.0580]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.2542]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.1521]], grad_fn=<TopkBackward0>),
# indices=tensor([[7]]))
# torch.return_types.topk(
# values=tensor([[-0.1742]], grad_fn=<TopkBackward0>),
# indices=tensor([[16]]))
# torch.return_types.topk(
# values=tensor([[-0.6620]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.6444]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.4125]], grad_fn=<TopkBackward0>),
# indices=tensor([[13]]))
# torch.return_types.topk(
# values=tensor([[-1.2800]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.6845]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.5531]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.6154]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-1.3322]], grad_fn=<TopkBackward0>),
# indices=tensor([[14]]))
# torch.return_types.topk(
# values=tensor([[-0.0480]], grad_fn=<TopkBackward0>),
# indices=tensor([[8]]))
# torch.return_types.topk(
# values=tensor([[-0.0496]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.3828]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-1.0209]], grad_fn=<TopkBackward0>),
# indices=tensor([[15]]))
# torch.return_types.topk(
# values=tensor([[-0.3273]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.9206]], grad_fn=<TopkBackward0>),
# indices=tensor([[2]]))
# torch.return_types.topk(
# values=tensor([[-1.0864]], grad_fn=<TopkBackward0>),
# indices=tensor([[10]]))
# torch.return_types.topk(
# values=tensor([[-0.3516]], grad_fn=<TopkBackward0>),
# indices=tensor([[0]]))
# torch.return_types.topk(
# values=tensor([[-0.4801]], grad_fn=<TopkBackward0>),
# indices=tensor([[1]]))
# torch.return_types.topk(
# values=tensor([[-0.2038]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.1274]], grad_fn=<TopkBackward0>),
# indices=tensor([[4]]))
# torch.return_types.topk(
# values=tensor([[-0.4176]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-0.1291]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-1.3012]], grad_fn=<TopkBackward0>),
# indices=tensor([[5]]))
# torch.return_types.topk(
# values=tensor([[-1.2677]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# torch.return_types.topk(
# values=tensor([[-0.1911]], grad_fn=<TopkBackward0>),
# indices=tensor([[3]]))
# torch.return_types.topk(
# values=tensor([[-1.3059]], grad_fn=<TopkBackward0>),
# indices=tensor([[11]]))
# torch.return_types.topk(
# values=tensor([[-0.0005]], grad_fn=<TopkBackward0>),
# indices=tensor([[9]]))
# <ipython-input-57-59cae0c54c29>:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([''] + all_categories, rotation=90)
# <ipython-input-57-59cae0c54c29>:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([''] + all_categories)

# %%
def predict(input_line, n_predictions=3):
    print('\n> %s' % input_line)
    with torch.no_grad():
        output = evaluate(lineToTensor(input_line))

        # Get top N categories
        topv, topi = output.topk(n_predictions, 1, True)
        predictions = []

        for i in range(n_predictions):
            value = topv[0][i].item()
            category_index = topi[0][i].item()
            print('(%.2f) %s' % (value, all_categories[category_index]))
            predictions.append([value, all_categories[category_index]])

predict('Dovesky')
predict('Jackson')
predict('Satoshi')
# Out:
# > Dovesky
# (-0.65) Czech
# (-1.07) Russian
# (-2.49) English
#
# > Jackson
# (-0.35) Russian
# (-1.80) Czech
# (-2.50) Scottish
#
# > Satoshi
# (-0.51) Japanese
# (-1.32) Italian
# (-2.59) Arabic

# %%
predict('Wong')
# Out:
# > Wong
# (-1.48) Chinese
# (-1.66) German
# (-1.73) Scottish
